# %% [markdown]
# # Objective - Basic Data Exploration and Cleaning using Pandas

# %% [markdown]
# ## Step 1 : Loading data

# %%
import pandas as pd

df = pd.read_csv("..//WEEK-1//combined_dataset.csv")

df
# Out:
#      product_id           title  \
# 0       8376765     Lino Perros
# 1       9136281  Tommy Hilfiger
# 2      17633752           Lavie
# 3       1376949          F Gear
# 4      13939916       MYTRIDENT
# ..          ...             ...
# 995    13698258           KREDO
# 996    16896006           GUESS
# 997     1708108        GIORDANO
# 998    19280114        Fastrack
# 999    18601682         BOLDFIT
#
#                                    product_description  rating  ratings_count  \
# 0                       Women Navy Blue Solid Backpack     3.8             15
# 1                    Unisex Navy Blue Striped Backpack     4.5             67
# 2                       Aries Women Pink Mini Backpack     4.4            226
# 3           Unisex Navy & Grey Printed Burner Backpack     4.4           1052
# 4                             Men Blue Solid Bath Robe     4.7             12
# ..                                                 ...     ...            ...
# ...

# %% [markdown]
# ## Step 2 : Data Exploration ( head/tail, shape, columns, datatypes)

# %%
print("Shape:", df.shape)
print("Columns:", df.columns)
# Out:
# Shape: (1000, 24)
# Columns: Index(['product_id', 'title', 'product_description', 'rating', 'ratings_count',
#        'initial_price', 'discount', 'final_price', 'currency', 'images',
#        'delivery_options', 'product_details', 'breadcrumbs',
#        'product_specifications', 'amount_of_stars', 'what_customers_said',
#        'seller_name', 'sizes', 'videos', 'seller_information', 'variations',
#        'best_offer', 'more_offers', 'category'],
#       dtype='str')

# %%
df.head()
# Out:
#    product_id           title                         product_description  \
# 0     8376765     Lino Perros              Women Navy Blue Solid Backpack
# 1     9136281  Tommy Hilfiger           Unisex Navy Blue Striped Backpack
# 2    17633752           Lavie              Aries Women Pink Mini Backpack
# 3     1376949          F Gear  Unisex Navy & Grey Printed Burner Backpack
# 4    13939916       MYTRIDENT                    Men Blue Solid Bath Robe
#
#    rating  ratings_count  initial_price  discount  final_price currency  \
# 0     3.8             15           3995      58.0  "₹3,995.00"      INR
# 1     4.5             67           2899      35.0  "₹2,899.00"      INR
# 2     4.4            226           2999      65.0  "₹2,999.00"      INR
# 3     4.4           1052           1675      52.0  "₹1,675.00"      INR
# 4     4.7             12           2899      17.0  "₹2,899.00"      INR
#
#                                               images  ...  \
# ...

# %%
df.tail()
# Out:
#      product_id     title                                product_description  \
# 995    13698258     KREDO  Men FORTE Silver Automatic Skeleton Analogue W...
# 996    16896006     GUESS  Women White Patterned Dial & White Straps Anal...
# 997     1708108  GIORDANO  Women Rose Gold-Toned Mirrored Analogue Watch ...
# 998    19280114  Fastrack  Men Black Brass Dial & Black Stainless Steel S...
# 999    18601682   BOLDFIT                           Purple Textured Yoga Mat
#
#      rating  ratings_count  initial_price  discount   final_price currency  \
# 995     3.5             11          11890      50.0  "₹11,890.00"      INR
# 996     5.0             22           8900      45.0   "₹8,900.00"      INR
# 997     2.8              5           7950      50.0   "₹7,950.00"      INR
# 998     4.3             17           3295      20.0   "₹2,636.00"      INR
# 999     3.8            161            699      31.0     "₹699.00"      INR
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   product_id              1000 non-null   int64
#  1   title                   1000 non-null   str
#  2   product_description     1000 non-null   str
#  3   rating                  1000 non-null   float64
#  4   ratings_count           1000 non-null   int64
#  5   initial_price           1000 non-null   int64
#  6   discount                879 non-null    float64
#  7   final_price             1000 non-null   str
#  8   currency                1000 non-null   str
#  9   images                  1000 non-null   str
#  10  delivery_options        1000 non-null   str
#  11  product_details         1000 non-null   str
#  12  breadcrumbs             1000 non-null   str
#  13  product_specifications  1000 non-null   str
#  14  amount_of_stars         1000 non-null   str
# ...

# %%
df.describe()
# Out:
#          product_id     rating  ratings_count  initial_price    discount
# count  1.000000e+03  1000.0000    1000.000000     1000.00000  879.000000
# mean   1.713437e+07     3.6215      76.691000     2723.24100   53.503982
# std    3.813766e+06     1.3744     241.114263     2408.69736   18.029201
# min    5.868460e+05     0.0000       0.000000      249.00000    1.000000
# 25%    1.511501e+07     3.7000       7.000000     1399.00000   44.000000
# 50%    1.820890e+07     4.1000      17.000000     1999.00000   56.000000
# 75%    1.902737e+07     4.3000      58.000000     3299.00000   66.000000
# max    2.274707e+07     5.0000    4441.000000    22199.00000   88.000000

# %% [markdown]
# ## Step 3: Handling Missing Values ( Identify , fill/drop )

# %%
df.isnull().sum()
# Out:
# product_id                  0
# title                       0
# product_description         0
# rating                      0
# ratings_count               0
# initial_price               0
# discount                  121
# final_price                 0
# currency                    0
# images                      0
# delivery_options            0
# product_details             0
# breadcrumbs                 0
# product_specifications      0
# amount_of_stars             0
# what_customers_said       573
# seller_name               301
# sizes                       0
# videos                    781
# seller_information        301
# variations                562
# best_offer                  0
# more_offers                 0
# category                    0
# dtype: int64

# %%
df_cleaned = df.copy()

# %%
df_cleaned['discount'] = df_cleaned['discount'].fillna(0)
df_cleaned['seller_name'] = df_cleaned['seller_name'].fillna("Unknown")

# %%
df_cleaned['what_customers_said'] = df_cleaned['what_customers_said'].fillna("No review")
df_cleaned['seller_information'] = df_cleaned['seller_information'].fillna("Not available")

# %%
df_cleaned['initial_price'] = df_cleaned['initial_price'].fillna(0)
df_cleaned['ratings_count'] = df_cleaned['ratings_count'].fillna(0)

# %%
df_cleaned.isnull().sum()

# %% [markdown]
# ## Step 4 : Performing Basic Operations ( filter rows , select columns)

# %%
df_cleaned[['title', 'final_price', 'rating']].head()
# Out:
#             title  final_price  rating
# 0     Lino Perros  "₹3,995.00"     3.8
# 1  Tommy Hilfiger  "₹2,899.00"     4.5
# 2           Lavie  "₹2,999.00"     4.4
# 3          F Gear  "₹1,675.00"     4.4
# 4       MYTRIDENT  "₹2,899.00"     4.7

# %%
df_cleaned[df_cleaned['rating'] > 4]
# Out:
#      product_id              title  \
# 1       9136281     Tommy Hilfiger
# 2      17633752              Lavie
# 3       1376949             F Gear
# 4      13939916          MYTRIDENT
# 5      17198778                H&M
# ..          ...                ...
# 991     2466414       Daniel Klein
# 992    11791782              CASIO
# 994     8481603  French Connection
# 996    16896006              GUESS
# 998    19280114           Fastrack
#
#                                    product_description  rating  ratings_count  \
# 1                    Unisex Navy Blue Striped Backpack     4.5             67
# 2                       Aries Women Pink Mini Backpack     4.4            226
# 3           Unisex Navy & Grey Printed Burner Backpack     4.4           1052
# 4                             Men Blue Solid Bath Robe     4.7             12
# 5           Beige & Tan Solid Stoneware Soap Dispenser     4.5             42
# ...

# %%
df_cleaned['final_price'] = pd.to_numeric(df_cleaned['final_price'], errors='coerce')

# %%
df_cleaned[(df_cleaned['rating'] > 4) & (df_cleaned['final_price'] < 100)]
# Out:
# Empty DataFrame
# Columns: [product_id, title, product_description, rating, ratings_count, initial_price, discount, final_price, currency, images, delivery_options, product_details, breadcrumbs, product_specifications, amount_of_stars, what_customers_said, seller_name, sizes, seller_information, best_offer, more_offers, category]
# Index: []
#
# [0 rows x 22 columns]

# %%
df_cleaned.dtypes
# Out:
# product_id                  int64
# title                         str
# product_description           str
# rating                    float64
# ratings_count               int64
# initial_price               int64
# discount                  float64
# final_price               float64
# currency                      str
# images                        str
# delivery_options              str
# product_details               str
# breadcrumbs                   str
# product_specifications        str
# amount_of_stars               str
# what_customers_said           str
# seller_name                   str
# sizes                         str
# seller_information            str
# best_offer                    str
# more_offers                   str
# category                      str
# dtype: object

# %% [markdown]
# ## Step 5 : Removing Duplicates

# %%
df_cleaned = df_cleaned.drop_duplicates()

# %%
df_cleaned.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Step 6 : Creating a Derived Column ( total_amount = price * quantity )

# %%
df_cleaned[['initial_price', 'ratings_count']].info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   initial_price  1000 non-null   int64
#  1   ratings_count  1000 non-null   int64
# dtypes: int64(2)
# memory usage: 15.8 KB

# %%
df_cleaned['initial_price'] = df_cleaned['initial_price'].astype(str)

df_cleaned['initial_price'] = df_cleaned['initial_price'].str.replace('[^0-9.]', '', regex=True)

df_cleaned['initial_price'] = pd.to_numeric(df_cleaned['initial_price'], errors='coerce')

# %%
df_cleaned['total_amount'] = df_cleaned['initial_price'] * df_cleaned['ratings_count']

# %%
df_cleaned[['initial_price', 'ratings_count', 'total_amount']].head()
# Out:
#    initial_price  ratings_count  total_amount
# 0           3995             15         59925
# 1           2899             67        194233
# 2           2999            226        677774
# 3           1675           1052       1762100
# 4           2899             12         34788

# %% [markdown]
# ## Step 7 : Final Output

# %%
df_final = df_cleaned[['title','initial_price','ratings_count','total_amount']]

# %%
df_final = df_final.sort_values(by='total_amount', ascending=False)
df_final.head()
# Out:
#             title  initial_price  ratings_count  total_amount
# 21        Mactree           9060           1727      15646620
# 117        Athena           2799           3797      10627803
# 143     SASSAFRAS           2199           4441       9765759
# 991  Daniel Klein           6950            940       6533000
# 473          Biba           4995            749       3741255

# %%
df_final.to_csv("cleaned_dataset.csv", index=False)

# %% [markdown]
# ## Summary
#
# This Assignment involved cleaning and preprocessing an e-commerce dataset to make it suitable for analysis. Initially, the dataset was explored to understand its structure and identify missing or inconsistent values. Data cleaning steps included handling missing values, converting data types (such as price fields), and removing unnecessary symbols. Duplicate records were identified and removed to ensure data quality. Basic operations like filtering rows and selecting relevant columns were performed. Finally, the cleaned dataset was saved as a CSV file for further analysis.
# This process improves data quality and ensures accurate analysis results.
